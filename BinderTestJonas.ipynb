# %% [markdown]
# # How to: Creating reproducible workflows w. Jupyter notebook
# ---

# %% [markdown]
# This notebook is an example of how to create a reproducible workflow using Jupyter notebook and python.
# There are 4 steps that make this workflow reproducible:
# 1. [Import necesarry files](#data)
# 2. [Automate data manipulation](#manipulation)
# 3. [Define seeds to generate random numbers](#seeds)
# 4. [Print dependences](#dependencies)

# %% [markdown]
# ---

# %%
# install necessary libraries
import sys
#!pip install pandas numpy altair vega vega_datasets watermark altair_viewer
# Out:
# Requirement already satisfied: pandas in c:\users\51019\anaconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: numpy in c:\users\51019\anaconda3\lib\site-packages (1.18.1)
# Requirement already satisfied: altair in c:\users\51019\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: vega in c:\users\51019\anaconda3\lib\site-packages (3.4.0)
# Requirement already satisfied: vega_datasets in c:\users\51019\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: watermark in c:\users\51019\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: altair_viewer in c:\users\51019\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\51019\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\51019\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: toolz in c:\users\51019\anaconda3\lib\site-packages (from altair) (0.10.0)
# Requirement already satisfied: jinja2 in c:\users\51019\anaconda3\lib\site-packages (from altair) (2.11.2)
# Requirement already satisfied: entrypoints in c:\users\51019\anaconda3\lib\site-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema in c:\users\51019\anaconda3\lib\site-packages (from altair) (3.2.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\51019\anaconda3\lib\site-packages (from vega) (1.0.0)
# Requirement already satisfied: ipython in c:\users\51019\anaconda3\lib\site-packages (from watermark) (7.13.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in c:\users\51019\anaconda3\lib\site-packages (from altair_viewer) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\51019\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\51019\anaconda3\lib\site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\51019\anaconda3\lib\site-packages (from jsonschema->altair) (47.1.1.post20200604)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\51019\anaconda3\lib\site-packages (from jsonschema->altair) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\51019\anaconda3\lib\site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\51019\anaconda3\lib\site-packages (from jsonschema->altair) (1.6.0)
# Requirement already satisfied: ipykernel in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (5.1.4)
# Requirement already satisfied: nbconvert in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (5.6.1)
# Requirement already satisfied: jupyter-console in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.1.0)
# Requirement already satisfied: qtconsole in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (4.7.4)
# Requirement already satisfied: notebook in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.0.3)
# Requirement already satisfied: ipywidgets in c:\users\51019\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->vega) (7.5.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (4.3.3)
# Requirement already satisfied: backcall in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (0.15.2)
# Requirement already satisfied: pygments in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (2.6.1)
# Requirement already satisfied: decorator in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (3.0.5)
# Requirement already satisfied: pickleshare in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\51019\anaconda3\lib\site-packages (from ipython->watermark) (0.4.3)
# Requirement already satisfied: tornado in c:\users\51019\anaconda3\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.0.4)
# Requirement already satisfied: portpicker in c:\users\51019\anaconda3\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\51019\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair) (3.1.0)
# Requirement already satisfied: jupyter-client in c:\users\51019\anaconda3\lib\site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (6.1.7)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.8.4)
# Requirement already satisfied: jupyter-core in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (4.6.3)
# Requirement already satisfied: testpath in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.4.4)
# Requirement already satisfied: bleach in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (3.1.4)
# Requirement already satisfied: nbformat>=4.4 in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (5.0.6)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\51019\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.6.0)
# Requirement already satisfied: pyzmq>=17.1 in c:\users\51019\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->vega) (18.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\51019\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->vega) (0.2.0)
# Requirement already satisfied: qtpy in c:\users\51019\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->vega) (1.9.0)
# Requirement already satisfied: prometheus-client in c:\users\51019\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (0.7.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\51019\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (0.8.3)
# Requirement already satisfied: Send2Trash in c:\users\51019\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->vega) (1.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\51019\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->vega) (3.5.1)
# Requirement already satisfied: parso>=0.5.2 in c:\users\51019\anaconda3\lib\site-packages (from jedi>=0.10->ipython->watermark) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\51019\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.1.9)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\51019\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (227)
# Requirement already satisfied: webencodings in c:\users\51019\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.5.1)

# %%
# Import necesarry libraries
import pandas as pd  
import numpy  as np
# from   geopy.geocoders import Nominatim
import altair as alt
import vega 
from   vega_datasets import data # for state contours

# %%
alt.renderers.enable('notebook'); # for rendering in jupyter notebook 
# /there is a bug in this renderer sometimes, hence the later workaround in included

# %% [markdown]
# ---
# <a name = "data"></a>
# ## 1. Import necesarry files

# %%
# define file name
file_name  = "cart_segm_literature.csv"

# %%
# load literature table
literature = pd.read_csv("./" + file_name)

# %%
# show data

# display all rows and columns
dataDimension = literature.shape # get number of rows
pd.set_option("display.max_rows",5)
pd.set_option("display.max_columns",dataDimension[1])

# show
literature
# Out:
#     Unnamed: 0   algorithm_type      bibtex_id     author_1         author_2  \
# 0            0  active contours  Solloway_1997  ﻿Solloway S    Hutchinson CE
# 1            1  active contours   Vincent_2011   ﻿Vincent G   Wolstenholme C
# ..         ...              ...            ...          ...              ...
# 27          27           hybrid      Seim_2010       Seim H    Kainmueller D
# 28          28           hybrid       Dam_2015     Dam ﻿E B       Lillholm M
#
#         author_3        author_4       author_5    author6 author_7 author_8  \
# 0    Waterton JC       Taylor CJ            NaN        NaN      NaN      NaN
# 1        Scott I         Bowes M            NaN        NaN      NaN      NaN
# ..           ...             ...            ...        ...      ...      ...
# 27    Lamecker H   Bindernagel M   Malinowski J   Zachow S      NaN      NaN
# 28     Marques J       Nielsen M            NaN        NaN      NaN      NaN
#
#                               affiliation_last_author city_last_author  \
# 0   Department of Medical Biophysics, University o...       Manchester
# 1                                      Imorphics Ltd.       Manchester
# ..                                                ...              ...
# 27  Zuse Institute Berlin (ZIB), Medical Planning ...           Berlin
# 28              Biomediq and University of Copenhagen       Copenhagen
#
#    country_last_author                                              title  \
# 0                   UK  ﻿The use of active shape models for making thi...
# 1                   UK  ﻿Fully Automatic Segmentation of the Knee Join...
# ..                 ...                                                ...
# 27             Germany  ﻿Model-based auto-segmentation of knee bones a...
# 28             Denmark  Automatic segmentation of high- and low-field ...
#
#                                               journal  year  \
# 0                       ﻿Magn Reson Med 37(6):943–952  1997
# 1   ﻿MICCAI 2010 Workshop Medical Image Analysis f...  2011
# ..                                                ...   ...
# 27  ﻿Medical Image Analysis for the Clinic: A Gran...  2010
# 28  ﻿SPIE  Journal of Medical Imaging, vol. 2, pp....  2015
#
#                                        link_to_pubmed   latitude  longitude
# 0         https://www.ncbi.nlm.nih.gov/pubmed/9178247  53.479489  -2.245115
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  53.479489  -2.245115
# ..                                                ...        ...        ...
# 27                                                NaN  52.517037  13.388860
# 28       https://www.ncbi.nlm.nih.gov/pubmed/26158096  55.686724  12.570072
#
# [29 rows x 20 columns]

# %% [markdown]
# ---
# <a name = "manipulation"></a>
# ## 2. Automate data manipulation
#
# **Automatic** data manipulation does not compromise original data and keeps track of manipulations, making analyses reproducible. It is *discouraged* to do **manual** manipulation, as it compromizes original data, is prone to errors, and does not keep track of changes, making analyses hardly reproducible.
#
# - Change `bibtext_id` format from `author_year` to `author (year)` for better readability when hovering (e.g. from `Solloway_1997` to `Solloway (1997)`)

# %%
# replace underscore with space and opening bracket
literature["bibtex_id"] = literature["bibtex_id"].str.replace('_',' (')
# adding closing bracket
literature["bibtex_id"] = literature["bibtex_id"].astype(str) + ")"  

# show table
literature
# Out:
#     Unnamed: 0   algorithm_type        bibtex_id     author_1  \
# 0            0  active contours  Solloway (1997)  ﻿Solloway S
# 1            1  active contours   Vincent (2011)   ﻿Vincent G
# ..         ...              ...              ...          ...
# 27          27           hybrid      Seim (2010)       Seim H
# 28          28           hybrid       Dam (2015)     Dam ﻿E B
#
#            author_2      author_3        author_4       author_5    author6  \
# 0     Hutchinson CE   Waterton JC       Taylor CJ            NaN        NaN
# 1    Wolstenholme C       Scott I         Bowes M            NaN        NaN
# ..              ...           ...             ...            ...        ...
# 27    Kainmueller D    Lamecker H   Bindernagel M   Malinowski J   Zachow S
# 28       Lillholm M     Marques J       Nielsen M            NaN        NaN
#
#    author_7 author_8                            affiliation_last_author  \
# 0       NaN      NaN  Department of Medical Biophysics, University o...
# 1       NaN      NaN                                     Imorphics Ltd.
# ..      ...      ...                                                ...
# 27      NaN      NaN  Zuse Institute Berlin (ZIB), Medical Planning ...
# 28      NaN      NaN              Biomediq and University of Copenhagen
#
#    city_last_author country_last_author  \
# 0        Manchester                  UK
# 1        Manchester                  UK
# ..              ...                 ...
# 27           Berlin             Germany
# 28       Copenhagen             Denmark
#
#                                                 title  \
# 0   ﻿The use of active shape models for making thi...
# 1   ﻿Fully Automatic Segmentation of the Knee Join...
# ..                                                ...
# 27  ﻿Model-based auto-segmentation of knee bones a...
# 28  Automatic segmentation of high- and low-field ...
#
#                                               journal  year  \
# 0                       ﻿Magn Reson Med 37(6):943–952  1997
# 1   ﻿MICCAI 2010 Workshop Medical Image Analysis f...  2011
# ..                                                ...   ...
# 27  ﻿Medical Image Analysis for the Clinic: A Gran...  2010
# 28  ﻿SPIE  Journal of Medical Imaging, vol. 2, pp....  2015
#
#                                        link_to_pubmed   latitude  longitude
# 0         https://www.ncbi.nlm.nih.gov/pubmed/9178247  53.479489  -2.245115
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  53.479489  -2.245115
# ..                                                ...        ...        ...
# 27                                                NaN  52.517037  13.388860
# 28       https://www.ncbi.nlm.nih.gov/pubmed/26158096  55.686724  12.570072
#
# [29 rows x 20 columns]

# %% [markdown]
# ---
# <a name = "seeds"></a>
# ## 3. Define seeds to generate random numbers
#
# Algorithms create random numbers starting from a seed number (usually picked from the system clock) and following a set of instructions that output the wanted random number. **Fixing the seed number** allows to always compute the same random number.
#
# - Calculate latitude and longitude of `city_last_author` and add small random number to avoid overlap on map
# - *Note*: The cell below contains the commands to compute `latitude` and `longitude` from `city_last_author` using the `geopy` package. The cell is commented out because `geopy` often times out, affecting the execution of the notebook. For this reason, the columns `latitude` and `longitude` are already included in version 4 of the file `cart_segm_literature.csv` on Zenodo

# %%
# calculate latitute and longitude 
# (timeout error can happen. wait a bit, and rerun the cell)
# nom = Nominatim(user_agent="a_name") # specify a name to avoid timeout errors

# add latitude and longitude to literature
# literature["coordinates"] = literature["city_last_author"].apply(nom.geocode, timeout=5) # create the intermediate columm "coordinates" to take advantage of pandas apply() method
# literature["latitude"]    = literature["coordinates"].apply(lambda x: x.lat if x!=None else None) # take advantage of pandas apply() method to avoid for loop
# literature["longitude"]   = literature["coordinates"].apply(lambda x: x.lon if x!=None else None) 
# literature = literature.drop(columns="coordinates") # delete the column "coordinates" (altair will not be able to read it (even if not used))

# %%
# FIRST RUN
np.random.seed(seed=3) # if this is not present, the cell is not reproducible

# add randomness to latitude
random_lat = np.random.uniform(low=0.0, high=2.5, size=(len(literature["latitude"]),))
literature["latitude_random"] = literature["latitude"] + pd.Series(random_lat)

# add randomness to longitude
random_lon = np.random.uniform(low=0.0, high=2.5, size=(len(literature["longitude"]),))
literature["longitude_random"] = literature["longitude"] + pd.Series(random_lon)

# show 
pd.set_option("display.max_rows",3) # show only the first three rows
literature [["latitude", "latitude_random", "longitude", "longitude_random"]] # show only these columns
# Out:
#      latitude  latitude_random  longitude  longitude_random
# 0   53.479489        54.856484  -2.245115          0.095844
# ..        ...              ...        ...               ...
# 28  55.686724        56.656652  12.570072         14.436938
#
# [29 rows x 4 columns]

# %%
# SECOND RUN
np.random.seed(seed=3) # if this is not present, the cell is not reproducible

# add randomness to latitude
random_lat = np.random.uniform(low=0.0, high=2.5, size=(len(literature["latitude"]),))
literature["latitude_random"] = literature["latitude"] + pd.Series(random_lat)

# add randomness to longitude
random_lon = np.random.uniform(low=0.0, high=2.5, size=(len(literature["longitude"]),))
literature["longitude_random"] = literature["longitude"] + pd.Series(random_lon)

# show literature
pd.set_option("display.max_rows",3) # show only the first three rows
literature [["latitude", "latitude_random", "longitude", "longitude_random"]] # show only these columns
# Out:
#      latitude  latitude_random  longitude  longitude_random
# 0   53.479489        54.856484  -2.245115          0.095844
# ..        ...              ...        ...               ...
# 28  55.686724        56.656652  12.570072         14.436938
#
# [29 rows x 4 columns]

# %% [markdown]
# ## Visualize map
# - Show the interactive map

# %%
import altair as alt
alt.renderers.enable('altair_viewer')
# Out:
# RendererRegistry.enable('altair_viewer')

# %%
import altair as alt

# load a simple dataset as a pandas DataFrame
from vega_datasets import data
# import coordinates of countries to create the background map
countries = alt.topo_feature(data.world_110m.url, 'countries')

# create map
background = alt.Chart(countries).mark_geoshape(
    fill        = 'white',
    stroke      = 'lightgray',
    strokeWidth = 1.5
).project(
    "equirectangular"
).properties(
    width  = 1250,
    height = 750
)

# create points
points = alt.Chart(literature).mark_circle().encode(
    longitude = 'longitude_random:Q',
    latitude  = 'latitude_random:Q',
    size      = alt.value(100),
    color     = 'algorithm_type',
    tooltip   = 'bibtex_id' # name of each point when hovering
    
)

# show
background + points
# Out:
# Displaying chart at http://localhost:22346/

# %% [markdown]
# <a name="dependencies"></a>
# ## 4. Print dependences

# %% [markdown]
# Dependences are fundamental to record the **computational environment**.
#
# - Use [watermark](https://github.com/rasbt/watermark) to print version of python, ipython, and packages, and characteristics of the computer

# %%
# %load_ext watermark

# python, ipython, packages, and machine characteristics
# %watermark -v -m -p wget,pandas,numpy,geopy,altair,vega,vega_datasets,watermark 

# date
print (" ")
# %watermark -u -n -t -z
# Out:
# CPython 3.7.6
# IPython 7.13.0
#
# wget 3.2
# pandas 1.0.3
# numpy 1.18.1
# geopy 1.22.0
# altair 4.1.0
# vega 3.4.0
# vega_datasets 0.8.0
# watermark 2.0.2
#
# compiler   : MSC v.1916 64 bit (AMD64)
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : Intel64 Family 6 Model 142 Stepping 12, GenuineIntel
# CPU cores  : 8
# interpreter: 64bit
#
# last updated: Wed Sep 16 2020 17:16:58 Romance Daylight Time

# %%
# Automatically make requirements.txt file for the environment
# !pip freeze > requirements.txt
